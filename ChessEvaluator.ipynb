# %%
import io
import chess.pgn
import chess.engine

engine_path = 'C:/Users/Lazaros - Sai/Desktop/chess python/stockfish/stockfish-windows-x86-64-modern.exe'
skill_level = 5  # Adjust skill level as needed

def analyze_game(pgn_string):
    engine = chess.engine.SimpleEngine.popen_uci(engine_path)
    engine.configure({"Skill Level": skill_level})  # Set the skill level

    board = chess.Board()
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    moves = list(game.mainline_moves())

    for i in range(len(moves)):
        move = moves[i]
        board.push(move)
        evaluation_before = evaluate_position(engine, board)
        
        if i + 1 < len(moves):
            next_move = moves[i + 1]
            board.push(next_move)
            evaluation_after = evaluate_position(engine, board)
            move_quality = evaluate_move_quality(evaluation_before, evaluation_after)
            if move_quality == "Blunder":
                for j in range(i + 2, i + 4):  # Look ahead two moves only for blunders
                    if j < len(moves):
                        board.push(moves[j])
                        better_move = find_better_move(engine, board)
                        print(f"Move {board.fullmove_number}: {move} - Quality: {move_quality}")
                        if better_move:
                            print(f"Better Move: {better_move}")
                        print(board)  # Print the board after each move
                        board.pop()
            else:
                print(f"Move {board.fullmove_number}: {move} - Quality: {move_quality} - Evaluation: {evaluation_after}")
                print(board)  # Print the board after each move
            board.pop()

def evaluate_position(engine, board):
    result = engine.analyse(board, chess.engine.Limit(time=0.7))  # Adjust time limit as needed
    return result["score"].relative.score(mate_score=10000)

def evaluate_move_quality(evaluation_before, evaluation_after):
    if evaluation_after <= evaluation_before - 500:  # Missed win
        return "Missed Win"
    elif evaluation_after >= evaluation_before + 120:  # Blunder
        return "Blunder"
    elif abs(evaluation_after - evaluation_before) <= 50:  # Miss
        return "Miss"
    else:
        return "Good Move"

def find_better_move(engine, board):
    legal_moves = list(board.legal_moves)
    best_move = None
    best_score = -float('inf')
    for move in legal_moves:
        board.push(move)
        score = evaluate_position(engine, board)
        if score > best_score:
            best_score = score
            best_move = move
        board.pop()
    return best_move

# Example usage
pgn_string = "1. e4 e5 2. Nf3 Nc6 3. Bb5 a6 4. Ba4 Nf6 5. O-O Be7 6. Re1 b5 7. Bb3 d6 8. c3 O-O 9. h3 Nb8 10. d4 Nbd7 11. Nbd2 Bb7 12. Bc2 Re8 13. Nf1 Bf8 14. Ng3 g6 15. a4 c5 16. d5 c4 17. Bg5 h6 18. Be3 Nc5 19. Qd2 h5 20. Bg5 Be7 21. Rf1 Nfd7 22. Bxe7 Qxe7 23. Qh6 Qf8 24. Qg5 Qg7 25. Nh4 Nf6 26. f4 Nh7 27. Nhf5 Nxg5 28. Nxg7 Kxg7 29. fxg5 Reb8 30. Rf6 Rd8 31. h4 Rd7 32. axb5 axb5 33. Rxa8 Bxa8 34. Bd1 Nd3 35. Bxh5 gxh5 36. Nxh5+ Kg8 37. Rh6 Rd8 38. Nf6+ Kg7 39. Rh7+ Kg6 40. g4 1-0"
analyze_game(pgn_string)
# Out:
# Move 2: e2e4 - Quality: Good Move - Evaluation: 30
# r n b q k b n r
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
# Move 2: e7e5 - Quality: Good Move - Evaluation: -37
# r n b q k b n r
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
# Move 3: g1f3 - Quality: Good Move - Evaluation: 31
# r . b q k b n r
# p p p p . p p p
# . . n . . . . .
# . . . . p . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K B . R
# Move 3: b8c6 - Quality: Good Move - Evaluation: -35
# r . b q k b n r
# p p p p . p p p
# . . n . . . . .
# . B . . p . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R
# Move 4: f1b5 - Quality: Good Move - Evaluation: 36
# r . b q k b n r
# . p p p . p p p
# p . n . . . . .
# . B . . p . . .
# . . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R
# Move 4: a7a6 - Quality: Good Move - Evaluation: -36
# r . b q k b n r
# . p p p . p p p
# p . n . . . . .
# . . . . p . . .
# B . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R
# Move 5: b5a4 - Quality: Good Move - Evaluation: 36
# r . b q k b . r
# . p p p . p p p
# p . n . . n . .
# . . . . p . . .
# B . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q K . . R
# Move 5: g8f6 - Quality: Good Move - Evaluation: -40
# r . b q k b . r
# . p p p . p p p
# p . n . . n . .
# . . . . p . . .
# B . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q . R K .
# Move 6: e1g1 - Quality: Good Move - Evaluation: 51
# r . b q k . . r
# . p p p b p p p
# p . n . . n . .
# . . . . p . . .
# B . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q . R K .
# Move 6: f8e7 - Quality: Good Move - Evaluation: -49
# r . b q k . . r
# . p p p b p p p
# p . n . . n . .
# . . . . p . . .
# B . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q R . K .
# Move 7: f1e1 - Quality: Good Move - Evaluation: 51
# r . b q k . . r
# . . p p b p p p
# p . n . . n . .
# . p . . p . . .
# B . . . P . . .
# . . . . . N . .
# P P P P . P P P
# R N B Q R . K .
# Move 7: b7b5 - Quality: Good Move - Evaluation: -41
# r . b q k . . r
# . . p p b p p p
# p . n . . n . .
# . p . . p . . .
# . . . . P . . .
# . B . . . N . .
# P P P P . P P P
# R N B Q R . K .
# Move 8: a4b3 - Quality: Good Move - Evaluation: 46
# r . b q k . . r
# . . p . b p p p
# p . n p . n . .
# . p . . p . . .
# . . . . P . . .
# . B . . . N . .
# P P P P . P P P
# R N B Q R . K .
# Move 8: d7d6 - Quality: Good Move - Evaluation: -44
# r . b q k . . r
# . . p . b p p p
# p . n p . n . .
# . p . . p . . .
# . . . . P . . .
# . B P . . N . .
# P P . P . P P P
# R N B Q R . K .
# Move 9: c2c3 - Quality: Good Move - Evaluation: 42
# r . b q . r k .
# . . p . b p p p
# p . n p . n . .
# . p . . p . . .
# . . . . P . . .
# . B P . . N . .
# P P . P . P P P
# R N B Q R . K .
# Move 9: e8g8 - Quality: Good Move - Evaluation: -41
# r . b q . r k .
# . . p . b p p p
# p . n p . n . .
# . p . . p . . .
# . . . . P . . .
# . B P . . N . P
# P P . P . P P .
# R N B Q R . K .
# Move 10: h2h3 - Quality: Good Move - Evaluation: 52
# r n b q . r k .
# . . p . b p p p
# p . . p . n . .
# . p . . p . . .
# . . . . P . . .
# . B P . . N . P
# P P . P . P P .
# R N B Q R . K .
# Move 10: c6b8 - Quality: Good Move - Evaluation: -48
# r n b q . r k .
# . . p . b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . B P . . N . P
# P P . . . P P .
# R N B Q R . K .
# Move 11: d2d4 - Quality: Good Move - Evaluation: 55
# r . b q . r k .
# . . p n b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . B P . . N . P
# P P . . . P P .
# R N B Q R . K .
# Move 11: b8d7 - Quality: Good Move - Evaluation: -51
# r . b q . r k .
# . . p n b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . B P . . N . P
# P P . N . P P .
# R . B Q R . K .
# Move 12: b1d2 - Quality: Good Move - Evaluation: 40
# r . . q . r k .
# . b p n b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . B P . . N . P
# P P . N . P P .
# R . B Q R . K .
# Move 12: c8b7 - Quality: Good Move - Evaluation: -46
# r . . q . r k .
# . b p n b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . . P . . N . P
# P P B N . P P .
# R . B Q R . K .
# Move 13: b3c2 - Quality: Good Move - Evaluation: 46
# r . . q r . k .
# . b p n b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . . P . . N . P
# P P B N . P P .
# R . B Q R . K .
# Move 13: f8e8 - Quality: Good Move - Evaluation: -44
# r . . q r . k .
# . b p n b p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . . P . . N . P
# P P B . . P P .
# R . B Q R N K .
# Move 14: d2f1 - Quality: Good Move - Evaluation: 43
# r . . q r b k .
# . b p n . p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . . P . . N . P
# P P B . . P P .
# R . B Q R N K .
# Move 14: e7f8 - Quality: Good Move - Evaluation: -50
# r . . q r b k .
# . b p n . p p p
# p . . p . n . .
# . p . . p . . .
# . . . P P . . .
# . . P . . N N P
# P P B . . P P .
# R . B Q R . K .
# Move 15: f1g3 - Quality: Good Move - Evaluation: 60
# r . . q r b k .
# . b p n . p . p
# p . . p . n p .
# . p . . p . . .
# . . . P P . . .
# . . P . . N N P
# P P B . . P P .
# R . B Q R . K .
# Move 15: g7g6 - Quality: Good Move - Evaluation: -47
# r . . q r b k .
# . b p n . p . p
# p . . p . n p .
# . p . . p . . .
# P . . P P . . .
# . . P . . N N P
# . P B . . P P .
# R . B Q R . K .
# Move 16: a2a4 - Quality: Good Move - Evaluation: 57
# r . . q r b k .
# . b . n . p . p
# p . . p . n p .
# . p p . p . . .
# P . . P P . . .
# . . P . . N N P
# . P B . . P P .
# R . B Q R . K .
# Move 16: c7c5 - Quality: Good Move - Evaluation: -54
# r . . q r b k .
# . b . n . p . p
# p . . p . n p .
# . p p P p . . .
# P . . . P . . .
# . . P . . N N P
# . P B . . P P .
# R . B Q R . K .
# Move 17: d4d5 - Quality: Good Move - Evaluation: 48
# r . . q r b k .
# . b . n . p . p
# p . . p . n p .
# . p . P p . . .
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . B Q R . K .
# Move 17: c5c4 - Quality: Good Move - Evaluation: -48
# r . . q r b k .
# . b . n . p . p
# p . . p . n p .
# . p . P p . B .
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . . Q R . K .
# Move 18: c1g5 - Quality: Good Move - Evaluation: 55
# r . . q r b k .
# . b . n . p . .
# p . . p . n p p
# . p . P p . B .
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . . Q R . K .
# Move 18: h7h6 - Quality: Good Move - Evaluation: -53
# r . . q r b k .
# . b . n . p . .
# p . . p . n p p
# . p . P p . . .
# P . p . P . . .
# . . P . B N N P
# . P B . . P P .
# R . . Q R . K .
# Move 19: g5e3 - Quality: Good Move - Evaluation: 53
# r . . q r b k .
# . b . . . p . .
# p . . p . n p p
# . p n P p . . .
# P . p . P . . .
# . . P . B N N P
# . P B . . P P .
# R . . Q R . K .
# Move 19: d7c5 - Quality: Good Move - Evaluation: -47
# r . . q r b k .
# . b . . . p . .
# p . . p . n p p
# . p n P p . . .
# P . p . P . . .
# . . P . B N N P
# . P B Q . P P .
# R . . . R . K .
# Move 20: d1d2 - Quality: Good Move - Evaluation: 51
# r . . q r b k .
# . b . . . p . .
# p . . p . n p .
# . p n P p . . p
# P . p . P . . .
# . . P . B N N P
# . P B Q . P P .
# R . . . R . K .
# Move 20: h6h5 - Quality: Good Move - Evaluation: -49
# r . . q r b k .
# . b . . . p . .
# p . . p . n p .
# . p n P p . B p
# P . p . P . . .
# . . P . . N N P
# . P B Q . P P .
# R . . . R . K .
# Move 21: e3g5 - Quality: Good Move - Evaluation: 55
# r . . q r . k .
# . b . . b p . .
# p . . p . n p .
# . p n P p . B p
# P . p . P . . .
# . . P . . N N P
# . P B Q . P P .
# R . . . R . K .
# Move 21: f8e7 - Quality: Good Move - Evaluation: -9
# r . . q r . k .
# . b . . b p . .
# p . . p . n p .
# . p n P p . B p
# P . p . P . . .
# . . P . . N N P
# . P B Q . P P .
# R . . . . R K .
# Move 22: e1f1 - Quality: Miss - Evaluation: 32
# r . . q r . k .
# . b . n b p . .
# p . . p . . p .
# . p n P p . B p
# P . p . P . . .
# . . P . . N N P
# . P B Q . P P .
# R . . . . R K .
# Move 22: f6d7 - Quality: Good Move - Evaluation: -17
# r . . q r . k .
# . b . n B p . .
# p . . p . . p .
# . p n P p . . p
# P . p . P . . .
# . . P . . N N P
# . P B Q . P P .
# R . . . . R K .
# Move 23: g5e7 - Quality: Miss - Evaluation: 25
# r . . . r . k .
# . b . n q p . .
# p . . p . . p .
# . p n P p . . p
# P . p . P . . .
# . . P . . N N P
# . P B Q . P P .
# R . . . . R K .
# Move 23: d8e7 - Quality: Good Move - Evaluation: -26
# r . . . r . k .
# . b . n q p . .
# p . . p . . p Q
# . p n P p . . p
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . . . . R K .
# Move 24: d2h6 - Quality: Miss - Evaluation: 27
# r . . . r q k .
# . b . n . p . .
# p . . p . . p Q
# . p n P p . . p
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . . . . R K .
# Move 24: e7f8 - Quality: Miss - Evaluation: -16
# r . . . r q k .
# . b . n . p . .
# p . . p . . p .
# . p n P p . Q p
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . . . . R K .
# Move 25: h6g5 - Quality: Miss - Evaluation: 23
# r . . . r . k .
# . b . n . p q .
# p . . p . . p .
# . p n P p . Q p
# P . p . P . . .
# . . P . . N N P
# . P B . . P P .
# R . . . . R K .
# Move 25: f8g7 - Quality: Miss - Evaluation: 37
# r . . . r . k .
# . b . n . p q .
# p . . p . . p .
# . p n P p . Q p
# P . p . P . . N
# . . P . . . N P
# . P B . . P P .
# R . . . . R K .
# Move 26: f3h4 - Quality: Miss - Evaluation: 5
# r . . . r . k .
# . b . . . p q .
# p . . p . n p .
# . p n P p . Q p
# P . p . P . . N
# . . P . . . N P
# . P B . . P P .
# R . . . . R K .
# Move 26: d7f6 - Quality: Miss - Evaluation: 52
# r . . . r . k .
# . b . . . p q .
# p . . p . n p .
# . p n P p . Q p
# P . p . P P . N
# . . P . . . N P
# . P B . . . P .
# R . . . . R K .
# Move 27: f2f4 - Quality: Good Move - Evaluation: -51
# r . . . r . k .
# . b . . . p q n
# p . . p . . p .
# . p n P p . Q p
# P . p . P P . N
# . . P . . . N P
# . P B . . . P .
# R . . . . R K .
# Exception parsing pv from info: 'depth 1 seldepth 1 multipv 1 score cp 50 nodes 441 nps 441000 hashfull 0 tbhits 0 time 1 pv h7g5 f5g7 g8g7 f4g5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 2 seldepth 2 multipv 1 score cp 50 nodes 614 nps 614000 hashfull 0 tbhits 0 time 1 pv h7g5 f5g7 g8g7 f4g5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 3 seldepth 3 multipv 1 score cp 50 nodes 849 nps 424500 hashfull 0 tbhits 0 time 2 pv h7g5 f5g7 g8g7 f4g5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 4 seldepth 4 multipv 1 score cp 50 nodes 1059 nps 529500 hashfull 0 tbhits 0 time 2 pv h7g5 f5g7 g8g7 f4g5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 5 seldepth 5 multipv 1 score cp 50 nodes 1438 nps 719000 hashfull 0 tbhits 0 time 2 pv h7g5 f5g7 g8g7 f4g5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 6 seldepth 5 multipv 1 score cp 50 nodes 2050 nps 683333 hashfull 0 tbhits 0 time 3 pv h7g5 f5g7 g8g7 f4g5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 7 seldepth 6 multipv 1 score cp 137 nodes 5043 nps 720428 hashfull 2 tbhits 0 time 7 pv h7g5 f5g7 g8g7 f4g5 h5h4', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 8 seldepth 6 multipv 1 score cp 137 nodes 10952 nps 644235 hashfull 4 tbhits 0 time 17 pv h7g5 f5g7 g8g7 f4g5 h5h4', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 9 seldepth 7 multipv 1 score cp 262 nodes 15037 nps 683500 hashfull 4 tbhits 0 time 22 pv h7g5 f5g7 g8g7 f4g5 h5h4', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 10 seldepth 8 multipv 1 score cp 262 nodes 23134 nps 701030 hashfull 5 tbhits 0 time 33 pv h7g5 f5g7 g8g7 f4g5 h5h4 g3f5 g6f5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 11 seldepth 14 multipv 1 score cp 155 nodes 33605 nps 715000 hashfull 8 tbhits 0 time 47 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 b7c8 f4f5 c8d7 a4b5 a6b5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 12 seldepth 14 multipv 1 score cp 182 nodes 75440 nps 746930 hashfull 20 tbhits 0 time 101 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 b7c8 f4f5 c8d7 a4b5 a6b5', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 13 seldepth 14 multipv 1 score cp 197 nodes 123665 nps 758680 hashfull 34 tbhits 0 time 163 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 b7c8 f4f5 c8d7 a4b5 a6b5 a1a8 e8a8', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Move 28: f6h7 - Quality: Blunder
# Better Move: f1f3
# r . . . r . k .
# . b . . . p q .
# p . . p . . p .
# . p n P p N n p
# P . p . P P . .
# . . P . . . N P
# . P B . . . P .
# R . . . . R K .
# Exception parsing pv from info: 'depth 14 seldepth 20 multipv 1 score cp 234 nodes 170555 nps 748048 hashfull 57 tbhits 0 time 228 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 b7c8 f4f5 c8d7 f5f6 g7h6', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 15 seldepth 24 multipv 1 score cp 213 nodes 266424 nps 756886 hashfull 95 tbhits 0 time 352 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 e5f4 f1f4 b5a4 a1f1 e8e7 f4f6 e7d7 g3e2 b7c8', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 16 seldepth 20 multipv 1 score cp 228 nodes 321888 nps 759169 hashfull 113 tbhits 0 time 424 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 e5f4 f1f4 b5a4 a1f1 e8e7 f4f6 a8d8 g3e2 b7c8 e2d4 d8d7 d4c6 e7e8', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 17 seldepth 23 multipv 1 score cp 235 nodes 443277 nps 773607 hashfull 145 tbhits 0 time 573 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 e5f4 f1f4 b5a4 a1f1 e8e7 f4f6 a8d8 g3e2 b7c8 e2d4 c8h3 f1f3 e7b7', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# Exception parsing pv from info: 'depth 18 seldepth 23 multipv 1 score cp 239 nodes 536916 nps 765928 hashfull 185 tbhits 0 time 701 pv h7g5 f5g7 g5h3 g2h3 g8g7 h3h4 e5f4 f1f4 b5a4 a1f1 e8e7 f4f6 a8d8 g3e2 b7c8 e2d4 c8h3 f1f3 e7b7 g1h2 h3g4 f3f2', position at root: r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# UciAnalysisCommand failed after returning preliminary result (<Future finished result=<chess.engine...0021CA64D95E0>>)
# protocol: <UciProtocol (pid=12104)>
# transport: <_WindowsSubprocessTransport pid=12104 running stdin=<_ProactorWritePipeTransport fd=4068 read=<_OverlappedFuture pending cb=[_ProactorWritePipeTransport._pipe_closed()]>> stdout=<_ProactorReadPipeTransport fd=4072 read=<_OverlappedFuture pending cb=[_ProactorReadPipeTransport._loop_reading()]>> stderr=<_ProactorReadPipeTransport fd=4064 read=<_OverlappedFuture pending cb=[_ProactorReadPipeTransport._loop_reading()]>>>
# Traceback (most recent call last):
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\engine.py", line 1965, in _parse_uci_bestmove
#     move = board.push_uci(tokens[0].lower())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\__init__.py", line 3164, in push_uci
#     move = self.parse_uci(uci)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\__init__.py", line 3147, in parse_uci
#     raise IllegalMoveError(f"illegal uci: {uci!r} in {self.fen()}")
# chess.IllegalMoveError: illegal uci: 'e8b8' in r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\engine.py", line 1386, in _line_received
#     self.line_received(engine, line)
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\engine.py", line 1818, in line_received
#     self._bestmove(engine, line.split(" ", 1)[1])
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\engine.py", line 1841, in _bestmove
#     best = _parse_uci_bestmove(engine.board, arg)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Lazaros - Sai\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\engine.py", line 1967, in _parse_uci_bestmove
#     raise EngineError(err)
# chess.engine.EngineError: illegal uci: 'e8b8' in r2Qr1k1/1b3pnn/p2p2p1/1pnPp2p/P1p1PP2/2P3NP/1PB3P1/R4RK1 b - - 1 28
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[31], line 71
#      69 # Example usage
#      70 pgn_string = "1. e4 e5 2. Nf3 Nc6 3. Bb5 a6 4. Ba4 Nf6 5. O-O Be7 6. Re1 b5 7. Bb3 d6 8. c3 O-O 9. h3 Nb8 10. d4 Nbd7 11. Nbd2 Bb7 12. Bc2 Re8 13. Nf1 Bf8 14. Ng3 g6 15. a4 c5 16. d5 c4 17. Bg5 h6 18. Be3 Nc5 19. Qd2 h5 20. Bg5 Be7 21. Rf1 Nfd7 22. Bxe7 Qxe7 23. Qh6 Qf8 24. Qg5 Qg7 25. Nh4 Nf6 26. f4 Nh7 27. Nhf5 Nxg5 28. Nxg7 Kxg7 29. fxg5 Reb8 30. Rf6 Rd8 31. h4 Rd7 32. axb5 axb5 33. Rxa8 Bxa8 34. Bd1 Nd3 35. Bxh5 gxh5 36. Nxh5+ Kg8 37. Rh6 Rd8 38. Nf6+ Kg7 39. Rh7+ Kg6 40. g4 1-0"
# ---> 71 analyze_game(pgn_string)
#
# Cell In[31], line 31, in analyze_game(pgn_string)
#      29 if j < len(moves):
#      30     board.push(moves[j])
# ---> 31     better_move = find_better_move(engine, board)
#      32     print(f"Move {board.fullmove_number}: {move} - Quality: {move_quality}")
#      33     if better_move:
#
# Cell In[31], line 62, in find_better_move(engine, board)
#      60 for move in legal_moves:
#      61     board.push(move)
# ---> 62     score = evaluate_position(engine, board)
#      63     if score > best_score:
#      64         best_score = score
#
# Cell In[31], line 43, in evaluate_position(engine, board)
#      42 def evaluate_position(engine, board):
# ---> 43     result = engine.analyse(board, chess.engine.Limit(time=0.7))  # Adjust time limit as needed
#      44     return result["score"].relative.score(mate_score=10000)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\chess\engine.py:2996, in SimpleEngine.analyse(self, board, limit, multipv, game, info, root_moves, options)
#    2992     coro = asyncio.wait_for(
#    2993         self.protocol.analyse(board, limit, multipv=multipv, game=game, info=info, root_moves=root_moves, options=options),
#    2994         self._timeout_for(limit))
#    2995     future = asyncio.run_coroutine_threadsafe(coro, self.protocol.loop)
# -> 2996 return future.result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# TimeoutError:
